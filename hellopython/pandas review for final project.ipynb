# %%
## analysis of bee colonies data

# %%
# for this analysis I will be look at dataset from 
# this dataset contains

# %% [markdown]
# 1. how long is this dataset?
# 2. what is the total(sum)/average (mean) of a column of interest?
# 3. how long is this dataset once you filter to a ceratain column's value?
# 4. what are different values available in a single column?(unique values)
# 5. how frequently do these values appear in this column?(value_counts)
# 6. are there any columns that need to be cleaned with an apply function?
# 7. what are number of unique values in a single column?(nunique)
# 8. what is the max/min value of a select column?
# 9. what is the max/min value of a select column?
# 10. what are the sum/mean of a column once it's grouped?(groupby+)

# %%
import pandas as pd
import altair as alt

# %%
pd.set_option('display.max_columns', None) # does not truncate columns

# %%
## A set up

# %%
### Read in your data
# if your data is most likely a csv, though pandas can read lot of different datasets.
# if it is json file, check notebook 14

# %%
## read your data

# %%
bees = pd.read_csv('bees.csv')

# %%
#1

# %%
len(bees) # this dataset has 2669 entries
# Out:
# 2669

# %%
bees.duplicated().any() # are there duplicated lines?
# Out:
# False

# %%
bees[bees.duplicated()] # see duplicate rows
# Out:
# Empty DataFrame
# Columns: [Program, Year, Period, Week Ending, Geo Level, State, State ANSI, Ag District, Ag District Code, County, County ANSI, Zip Code, Region, watershed_code, Watershed, Commodity, Data Item, Domain, Domain Category, Value, CV (%)]
# Index: []

# %%
bees.head(1)
# Out:
#   Program  Year          Period  Week Ending Geo Level    State  State ANSI  \
# 0  SURVEY  2021  MARKETING YEAR          NaN     STATE  ALABAMA         1.0
#
#    Ag District  Ag District Code  County  County ANSI  Zip Code  Region  \
# 0          NaN               NaN     NaN          NaN       NaN     NaN
#
#    watershed_code  Watershed Commodity  \
# 0               0        NaN     HONEY
#
#                                            Data Item Domain Domain Category  \
# 0  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...  TOTAL   NOT SPECIFIED
#
#    Value  CV (%)
# 0  8,000     NaN

# %%
bees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2669 entries, 0 to 2668
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Program           2669 non-null   object
#  1   Year              2669 non-null   int64
#  2   Period            2669 non-null   object
#  3   Week Ending       0 non-null      float64
#  4   Geo Level         2669 non-null   object
#  5   State             2669 non-null   object
#  6   State ANSI        2613 non-null   float64
#  7   Ag District       0 non-null      float64
#  8   Ag District Code  0 non-null      float64
#  9   County            0 non-null      float64
#  10  County ANSI       0 non-null      float64
#  11  Zip Code          0 non-null      float64
#  12  Region            0 non-null      float64
#  13  watershed_code    2669 non-null   int64
#  14  Watershed         0 non-null      float64
#  15  Commodity         2669 non-null   object
# ...

# %%
# 7

# %%
# the value column is a string, even though it has numbers, it needs to be clean to an integer so we can do math

# %%
x = '8,000' # test case

# %%
# create a function

# %%
# a function that takes string type number to an integer type
def cleanValue(n):
    clean_n = n.replace(',', '')
    final_n = int(clean_n)
    # remove the comma and make the numner into a integer
    
    
    return final_n

# %%
cleanValue('9,000')
# Out:
# 9000

# %%
# create a new column that is derived from the Value column
bees['clean_value'] = bees['Value'].apply(cleanValue)

# %%
bees.head()
# Out:
#   Program  Year          Period  Week Ending Geo Level       State  \
# 0  SURVEY  2021  MARKETING YEAR          NaN     STATE     ALABAMA
# 1  SURVEY  2021  MARKETING YEAR          NaN     STATE     ARIZONA
# 2  SURVEY  2021  MARKETING YEAR          NaN     STATE    ARKANSAS
# 3  SURVEY  2021  MARKETING YEAR          NaN     STATE  CALIFORNIA
# 4  SURVEY  2021  MARKETING YEAR          NaN     STATE    COLORADO
#
#    State ANSI  Ag District  Ag District Code  County  County ANSI  Zip Code  \
# 0         1.0          NaN               NaN     NaN          NaN       NaN
# 1         4.0          NaN               NaN     NaN          NaN       NaN
# 2         5.0          NaN               NaN     NaN          NaN       NaN
# 3         6.0          NaN               NaN     NaN          NaN       NaN
# 4         8.0          NaN               NaN     NaN          NaN       NaN
#
#    Region  watershed_code  Watershed Commodity  \
# 0     NaN               0        NaN     HONEY
# ...

# %%
bees['clean_value'].sum()
# Out:
# 168187390

# %%
# but!!! there are 168 million bee colonies in US- Wrong.

# %%
# 5

# %%
bees.head(1)
# Out:
#   Program  Year          Period  Week Ending Geo Level    State  State ANSI  \
# 0  SURVEY  2021  MARKETING YEAR          NaN     STATE  ALABAMA         1.0
#
#    Ag District  Ag District Code  County  County ANSI  Zip Code  Region  \
# 0          NaN               NaN     NaN          NaN       NaN     NaN
#
#    watershed_code  Watershed Commodity  \
# 0               0        NaN     HONEY
#
#                                            Data Item Domain Domain Category  \
# 0  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...  TOTAL   NOT SPECIFIED
#
#    Value  CV (%)  clean_value
# 0  8,000     NaN         8000

# %%
bees.Year.unique() # this data go back all the way to 1987
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000,
#        1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989,
#        1988, 1987], dtype=int64)

# %%
bees.State.unique()
# Out:
# array(['ALABAMA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO',
#        'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA',
#        'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MICHIGAN',
#        'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA',
#        'NEW JERSEY', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO',
#        'OREGON', 'OTHER STATES', 'PENNSYLVANIA', 'SOUTH CAROLINA',
#        'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT',
#        'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN', 'WYOMING',
#        'CONNECTICUT', 'MARYLAND', 'MASSACHUSETTS', 'NEW MEXICO',
#        'OKLAHOMA', 'NEVADA', 'DELAWARE', 'NEW HAMPSHIRE', 'RHODE ISLAND'],
#       dtype=object)

# %%
# 10 group the data by year and get the number of bees colonies

# %%
bees.groupby('Year')['clean_value'].sum()
# Out:
# Year
# 1987     3316000
# 1988     3370000
# 1989     3528000
# 1990     3220000
# 1991     3211000
# 1992     3045000
# 1993     2875000
# 1994     2783000
# 1995     2655000
# 1996     2581000
# 1997     2631000
# 1998     2637000
# 1999     2652000
# 2000     2622000
# 2001     2550000
# 2002     2574000
# 2003     2599000
# 2004     2554000
# 2005     2409000
# 2006     2394000
# 2007     2443000
# 2008     2342000
# 2009     2498000
# 2010     2692000
# 2011     2491000
# 2012     2539000
# 2013     2641000
# 2014     2741000
# 2015    14342750
# 2016    14414650
# 2017    13863510
# 2018    13956860
# 2019    11677540
# 2020    14864770
# 2021     8474310
# Name: clean_value, dtype: int64

# %%
# 3

# %%
# look at 2021 only

# %%
bees_now = bees[bees['Year'] == 2021] # not accurate because of Period column

# %%
len(bees_now)
# Out:
# 133

# %%
# 6

# %%
bees_now.Period.value_counts() # how frequently do the Period column values appear in this dataframe
# Out:
# FIRST OF JAN      46
# FIRST OF APR      46
# MARKETING YEAR    41
# Name: Period, dtype: int64

# %%
# contact USDA
# I am looking for someone to help me answer questions around how bee colony surveys are conducted-
# I was looking at data from xx site-

# %%
# 4 filter on 'Period' then get totals by year

# %%
jan_counts = bees[bees['Period'] == 'FIRST OF JAN'] # filter dataframe to only contain 'first of jan' in period column

# %%
jan_counts.groupby('Year')['clean_value'].sum()
# Out:
# Year
# 2015    2824610
# 2016    2619940
# 2017    2641090
# 2018    2635220
# 2019    2671470
# 2020    2876100
# 2021    2923240
# Name: clean_value, dtype: int64

# %%
# 8
# still filter to 2021, but only for jan counts

# %%
jan_counts_2021 = jan_counts[jan_counts.Year == 2021]

# %%
len(jan_counts_2021)
# Out:
# 46

# %%
jan_counts_2021['State'].nunique() # there are 4 states without bee colonies(or hasn't been counted) - wrong
# Out:
# 46

# %%
jan_counts_2021['State'].unique() # there are 45 states and they grouped 5 states together
# Out:
# array(['ALABAMA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO',
#        'CONNECTICUT', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS',
#        'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE',
#        'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA',
#        'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEW JERSEY',
#        'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO',
#        'OKLAHOMA', 'OREGON', 'OTHER STATES', 'PENNSYLVANIA',
#        'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH',
#        'VERMONT', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN',
#        'WYOMING'], dtype=object)

# %%
# 9 which state as the most bee colonies in January of 2021

# %%
jan_counts_2021['clean_value'].max()
# Out:
# 1240000

# %%
jan_counts_2021['clean_value'].sum()
# Out:
# 2923240

# %%
1240000/2923240
# Out:
# 0.42418686115406196

# %%
# Filter database on max value

# %%
jan_counts_2021[jan_counts_2021['clean_value'] == jan_counts_2021['clean_value'].max()]
# Out:
#    Program  Year        Period  Week Ending Geo Level       State  State ANSI  \
# 44  SURVEY  2021  FIRST OF JAN          NaN     STATE  CALIFORNIA         6.0
#
#     Ag District  Ag District Code  County  County ANSI  Zip Code  Region  \
# 44          NaN               NaN     NaN          NaN       NaN     NaN
#
#     watershed_code  Watershed Commodity  \
# 44               0        NaN     HONEY
#
#                                             Data Item Domain Domain Category  \
# 44  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...  TOTAL   NOT SPECIFIED
#
#         Value  CV (%)  clean_value
# 44  1,240,000     NaN      1240000

# %%
# Focus on California

# %%
jan_counts
# Out:
#      Program  Year        Period  Week Ending Geo Level          State  \
# 41    SURVEY  2021  FIRST OF JAN          NaN     STATE        ALABAMA
# 42    SURVEY  2021  FIRST OF JAN          NaN     STATE        ARIZONA
# 43    SURVEY  2021  FIRST OF JAN          NaN     STATE       ARKANSAS
# 44    SURVEY  2021  FIRST OF JAN          NaN     STATE     CALIFORNIA
# 45    SURVEY  2021  FIRST OF JAN          NaN     STATE       COLORADO
# ...      ...   ...           ...          ...       ...            ...
# 1294  SURVEY  2015  FIRST OF JAN          NaN     STATE       VIRGINIA
# 1295  SURVEY  2015  FIRST OF JAN          NaN     STATE     WASHINGTON
# 1296  SURVEY  2015  FIRST OF JAN          NaN     STATE  WEST VIRGINIA
# 1297  SURVEY  2015  FIRST OF JAN          NaN     STATE      WISCONSIN
# 1298  SURVEY  2015  FIRST OF JAN          NaN     STATE        WYOMING
#
#       State ANSI  Ag District  Ag District Code  County  County ANSI  \
# ...

# %%
cali = jan_counts[jan_counts['State'] == 'CALIFORNIA']

# %%
cali.groupby('Year')['clean_value'].sum()
# Out:
# Year
# 2015    1440000
# 2016    1130000
# 2017    1170000
# 2018    1150000
# 2019    1140000
# 2020    1350000
# 2021    1240000
# Name: clean_value, dtype: int64

# %%
cali
# Out:
#      Program  Year        Period  Week Ending Geo Level       State  \
# 44    SURVEY  2021  FIRST OF JAN          NaN     STATE  CALIFORNIA
# 177   SURVEY  2020  FIRST OF JAN          NaN     STATE  CALIFORNIA
# 402   SURVEY  2019  FIRST OF JAN          NaN     STATE  CALIFORNIA
# 581   SURVEY  2018  FIRST OF JAN          NaN     STATE  CALIFORNIA
# 806   SURVEY  2017  FIRST OF JAN          NaN     STATE  CALIFORNIA
# 1031  SURVEY  2016  FIRST OF JAN          NaN     STATE  CALIFORNIA
# 1256  SURVEY  2015  FIRST OF JAN          NaN     STATE  CALIFORNIA
#
#       State ANSI  Ag District  Ag District Code  County  County ANSI  \
# 44           6.0          NaN               NaN     NaN          NaN
# 177          6.0          NaN               NaN     NaN          NaN
# 402          6.0          NaN               NaN     NaN          NaN
# 581          6.0          NaN               NaN     NaN          NaN
# 806          6.0          NaN               NaN     NaN          NaN
# ...

# %%
bees.sort_values('Year')
# Out:
#      Program  Year          Period  Week Ending Geo Level          State  \
# 2668  SURVEY  1987  MARKETING YEAR          NaN     STATE        WYOMING
# 2640  SURVEY  1987  MARKETING YEAR          NaN     STATE       MICHIGAN
# 2639  SURVEY  1987  MARKETING YEAR          NaN     STATE  MASSACHUSETTS
# 2638  SURVEY  1987  MARKETING YEAR          NaN     STATE       MARYLAND
# 2637  SURVEY  1987  MARKETING YEAR          NaN     STATE          MAINE
# ...      ...   ...             ...          ...       ...            ...
# 95    SURVEY  2021    FIRST OF APR          NaN     STATE         HAWAII
# 96    SURVEY  2021    FIRST OF APR          NaN     STATE          IDAHO
# 97    SURVEY  2021    FIRST OF APR          NaN     STATE       ILLINOIS
# 83    SURVEY  2021    FIRST OF JAN          NaN     STATE     WASHINGTON
# 0     SURVEY  2021  MARKETING YEAR          NaN     STATE        ALABAMA
#
#       State ANSI  Ag District  Ag District Code  County  County ANSI  \
# ...

# %%
# NOO
# (new value-old value) /old value
# for example: cali data? why increase 18%?
