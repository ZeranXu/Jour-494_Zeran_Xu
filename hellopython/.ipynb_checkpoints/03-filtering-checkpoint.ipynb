# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# How to check if columns are empty

# %%
df.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df[df["Age"].isna()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df[df["Survived"] == 1 ] # filter on those who survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Survived"] == 1) & (df["Pclass"]==3)] # filter where survived column is 1 AND where Pclass column is 3
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 838          839         1       3
# 855          856         1       3
# 858          859         1       3
# 869          870         1       3
# 875          876         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survived = df[df["Survived"] == 1 ]

# %%
survived.groupby("Pclass").size()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# dtype: int64

# %%
died = df[df["Survived"] == 0 ]

# %%
len(died)
# Out:
# 549

# %%
died.groupby("Pclass").size()
# Out:
# Pclass
# 1     80
# 2     97
# 3    372
# dtype: int64

# %%
df[df["Embarked"].isin(["C","Q"])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 5              6         0       3
# 9             10         1       2
# 16            17         0       3
# 19            20         1       3
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 885          886         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[~df["Embarked"].isin(["C","Q"])] #filtering by what you don't want
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
df[df["Embarked"] == "S"]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
df.sort_values("Name").head()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#         Sex   Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845    male  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746    male  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  female  35.0      1      1  C.A. 2673  20.25   NaN        S
# 308    male  30.0      1      0  P/PP 3381  24.00   NaN        C
# 874  female  28.0      1      0  P/PP 3381  24.00   NaN        C

# %% [markdown]
# Filter on a string that starts with a certain letter

# %%
df[df["Name"].str.startswith("A")]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 13            14         0       3
# 25            26         1       3
# 40            41         0       3
# 49            50         0       3
# 68            69         1       3
# 91            92         0       3
# 114          115         0       3
# 119          120         0       3
# 144          145         0       2
# 146          147         1       3
# 182          183         0       3
# 192          193         1       3
# 207          208         1       3
# 210          211         0       3
# 233          234         1       3
# 244          245         0       3
# 261          262         1       3
# 275          276         1       1
# 279          280         1       3
# 297          298         0       1
# 305          306         1       1
# 308          309         0       2
# 353          354         0       3
# 363          364         0       3
# ...

# %%
a_lastname = df[df["Name"].str.startswith("A")]

# %%
len(a_lastname)
# Out:
# 51

# %%
df[df["Name"].str.contains("Edith")].head()
# Out:
#      PassengerId  Survived  Pclass  \
# 151          152         1       1
# 166          167         1       1
# 268          269         1       1
# 356          357         1       1
# 863          864         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 151              Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 166         Chibnall, Mrs. (Edith Martha Bowerman)  female   NaN      0
# 268  Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 356                    Bowerman, Miss. Elsie Edith  female  22.0      0
# 863              Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
#
#      Parch    Ticket      Fare Cabin Embarked
# 151      0    113776   66.6000    C2        S
# 166      1    113505   55.0000   E33        S
# 268      1  PC 17582  153.4625  C125        S
# 356      1    113505   55.0000   E33        S
# 863      2  CA. 2343   69.5500   NaN        S

# %%
x= 5

# %%
x
# Out:
# 5
